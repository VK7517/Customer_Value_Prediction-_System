# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("../data/raw/Online Retail.csv")

# %%
data.head(10)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#        InvoiceDate  UnitPrice  CustomerID         Country
# 0  01-12-2010 8.26       2.55     17850.0  United Kingdom
# 1  01-12-2010 8.26       3.39     17850.0  United Kingdom
# ...

# %%
data.shape
# Out:
# (541909, 8)

# %%
data.info()
# In Customer Id there are 135080 null values 
# In Description there are 1454 null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
data.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
# There must be some outliers as max quantities are 80995 and minimum is -80995 
# similarly in unit price , minimum is -11062 also max is 38970

# %%
data.describe(include="all")
# Out:
#        InvoiceNo StockCode                         Description       Quantity  \
# count     541909    541909                              540455  541909.000000
# unique     25900      4070                                4223            NaN
# top       573585    85123A  WHITE HANGING HEART T-LIGHT HOLDER            NaN
# freq        1114      2313                                2369            NaN
# mean         NaN       NaN                                 NaN       9.552250
# std          NaN       NaN                                 NaN     218.081158
# min          NaN       NaN                                 NaN  -80995.000000
# 25%          NaN       NaN                                 NaN       1.000000
# 50%          NaN       NaN                                 NaN       3.000000
# 75%          NaN       NaN                                 NaN      10.000000
# max          NaN       NaN                                 NaN   80995.000000
#
# ...

# %%
data["CustomerID"].nunique()
# There are only 4372 Customers
# Out:
# 4372

# %%
data["InvoiceNo"].nunique()
# means every cumtomer averagly buy for 5 times
# Out:
# 25900

# %%
# How much customer purchase??
df = data.groupby("CustomerID")["InvoiceNo"].value_counts().reset_index()
round(df.groupby("CustomerID")["count"].mean(),2)
# plt.tight_layout()
# Out:
# CustomerID
# 12346.0     1.00
# 12347.0    26.00
# 12348.0     7.75
# 12349.0    73.00
# 12350.0    17.00
#            ...
# 18280.0    10.00
# 18281.0     7.00
# 18282.0     4.33
# 18283.0    47.25
# 18287.0    23.33
# Name: count, Length: 4372, dtype: float64

# %%
data.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
# Checked duplicated rows 
data[data.duplicated()]
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# 517       536409     21866        UNION JACK FLAG LUGGAGE TAG         1
# 527       536409     22866      HAND WARMER SCOTTY DOG DESIGN         1
# 537       536409     22900    SET 2 TEA TOWELS I LOVE LONDON          1
# 539       536409     22111       SCOTTIE DOG HOT WATER BOTTLE         1
# 555       536412     22327  ROUND SNACK BOXES SET OF 4 SKULLS         1
# ...          ...       ...                                ...       ...
# 541675    581538     22068        BLACK PIRATE TREASURE CHEST         1
# 541689    581538     23318     BOX OF 6 MINI VINTAGE CRACKERS         1
# 541692    581538     22992             REVOLVER WOODEN RULER          1
# 541699    581538     22694                       WICKER STAR          1
# 541701    581538     23343       JUMBO BAG VINTAGE CHRISTMAS          1
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
Total_Quantity_bought_by_customer = data.groupby("CustomerID")["Quantity"].sum().reset_index()

# %%
# How much quantity bought by customer
Total_Quantity_bought_by_customer
# Out:
#       CustomerID  Quantity
# 0        12346.0         0
# 1        12347.0      2458
# 2        12348.0      2341
# 3        12349.0       631
# 4        12350.0       197
# ...          ...       ...
# 4367     18280.0        45
# 4368     18281.0        54
# 4369     18282.0        98
# 4370     18283.0      1397
# 4371     18287.0      1586
#
# [4372 rows x 2 columns]

# %%
Total_Quantity_bought_by_customer = data.groupby("CustomerID").agg({
    "Quantity":"sum",
    "UnitPrice":"sum"
})

# %%
Total_Quantity_bought_by_customer
# Out:
#             Quantity  UnitPrice
# CustomerID
# 12346.0            0       2.08
# 12347.0         2458     481.21
# 12348.0         2341     178.71
# 12349.0          631     605.10
# 12350.0          197      65.30
# ...              ...        ...
# 18280.0           45      47.65
# 18281.0           54      39.36
# 18282.0           98      62.68
# 18283.0         1397    1220.93
# 18287.0         1586     104.55
#
# [4372 rows x 2 columns]

# %%
data[data["CustomerID"]==12346]
# Here Quantity of 12346 CustomerID are +74215 , -74215
# Out:
#       InvoiceNo StockCode                     Description  Quantity  \
# 61619    541431     23166  MEDIUM CERAMIC TOP STORAGE JAR     74215
# 61624   C541433     23166  MEDIUM CERAMIC TOP STORAGE JAR    -74215
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 61619  18-01-2011 10.01       1.04     12346.0  United Kingdom
# 61624  18-01-2011 10.17       1.04     12346.0  United Kingdom

# %%
data[data["UnitPrice"]==1.04]
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# 61619     541431     23166     MEDIUM CERAMIC TOP STORAGE JAR     74215
# 61624    C541433     23166     MEDIUM CERAMIC TOP STORAGE JAR    -74215
# 148290    549222     23076         ICE CREAM SUNDAE LIP GLOSS       240
# 170413    551292     23078           ICE CREAM PEN LIP GLOSS         96
# 170414    551292     23077                DOUGHNUT LIP GLOSS         60
# ...          ...       ...                                ...       ...
# 534311   C581145     23250      VINTAGE RED TRIM ENAMEL BOWL        -38
# 534934    581175     23483  HANGING  BUTTERFLY T-LIGHT HOLDER        72
# 540301    581476     23166     MEDIUM CERAMIC TOP STORAGE JAR        48
# 540418    581482     23251       VINTAGE RED ENAMEL TRIM MUG         96
# 541745    581571     23168       CLASSIC CAFE SUGAR DISPENSER        36
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
# Unique Values
data["Description"].nunique()
# Out:
# 4223

# %%
data["StockCode"].nunique()
# Out:
# 4070

# %%
data["Country"].nunique()
# Out:
# 38

# %%
data["InvoiceNo"].nunique()
# Out:
# 25900

# %%
(data["Quantity"]<0).sum()
# There are 10000 CustomerID has negative quantities
# Out:
# np.int64(10624)

# %%
(data["Quantity"]>0).sum()
# Out:
# np.int64(531285)

# %%
(data["UnitPrice"]<=0).sum()
# there are 2517 negative values
# Out:
# np.int64(2517)

# %%
(data["InvoiceNo"].str.startswith("C")).sum()
# There are 9288 cancelled transactions
# Out:
# np.int64(9288)

# %%
# there are 4372 customers 
# there are 135080 missing customerId  
# there are 9288 cancellations 
# there are 10000 negative Quantities
# there are 25900 unique invoices 
# there are 38 countries
